# %%
import pandas as pd
df = pd.read_csv('data/경찰청_범죄 발생 지역별 통계_20221231.csv', encoding='euc-kr')
df
# Out:
#      범죄대분류      범죄중분류     서울     부산     대구     인천    광주     대전    울산    세종  \
# 0     강력범죄       살인기수     35     29     16     14     1      6     8     2
# 1     강력범죄      살인미수등     68     24     15     38     2     11     7     3
# 2     강력범죄         강도    118     43     31     30    10     17    10     2
# 3     강력범죄         강간   1200    347    215    340   152    200   112    26
# 4     강력범죄       유사강간    219     83     43     61    32     34    14     6
# 5     강력범죄       강제추행   4358   1064    648   1030   391    500   311    73
# 6     강력범죄  기타강간강제추행등     35     14      9     16     8      2    10     1
# 7     강력범죄         방화    217     89     50     70    35     40    28     8
# 8     절도범죄       절도범죄  37594  13699   9792   8895  5204   6034  3283  1110
# 9     폭력범죄         상해   3353   2478   1568   1545   641    831   683   119
# 10    폭력범죄         폭행  26509   8474   5629   8040  3430   4166  2574   400
# ...

# %%
df['서울'] >= 50000
# Out:
# 범죄중분류
# 살인기수         False
# 살인미수등        False
# 강도           False
# 강간           False
# 유사강간         False
# 강제추행         False
# 기타강간강제추행등    False
# 방화           False
# 절도범죄         False
# 상해           False
# 폭행           False
# 체포감금         False
# 협박           False
# 약취유인         False
# 폭력행위등        False
# 공갈           False
# 손괴           False
# 직무유기         False
# 직권남용         False
# 증수뢰          False
# 통화           False
# 문서인장         False
# 유가증권인지       False
# 사기            True
# 횡령           False
# 배임           False
# 성풍속범죄        False
# 도박범죄         False
# 특별경제범죄       False
# 마약범죄         False
# 보건범죄         False
# 환경범죄         False
# 교통범죄         False
# 노동범죄         False
# 안보범죄         False
# 선거범죄         False
# 병역범죄         False
# 기타범죄         False
# Name: 서울, dtype: bool

# %%
filt = (df['서울'] <= 100)
df[filt]
# Out:
#           범죄대분류  서울   부산  대구  인천  광주  대전  울산  세종  경기 고양  ...  경남 밀양  경남 사천  \
# 범죄중분류                                                    ...
# 살인기수       강력범죄  35   29  16  14   1   6   8   2      6  ...      1      2
# 살인미수등      강력범죄  68   24  15  38   2  11   7   3      8  ...      2      0
# 기타강간강제추행등  강력범죄  35   14   9  16   8   2  10   1      4  ...      1      1
# 약취유인       폭력범죄  72   17   7  18   8   2   5   2     10  ...      0      0
# 증수뢰        지능범죄  71   17   7  21  11  13   7   1      2  ...      0      0
# 유가증권인지     지능범죄  25    7   3   0   1   0   0   0      2  ...      0      0
# 환경범죄       환경범죄  50  243  16  87   7  23  29   7     46  ...     36     46
# 노동범죄       노동범죄  83   37  19  14   9  21   1   0     21  ...      1      1
# 안보범죄       안보범죄  61   13   6   7   4   4   4   2      0  ...      0      0
#
#            경남 양산  경남 진주  경남 창원  경남 통영  제주 서귀포  제주 제주  기타도시  도시이외
# 범죄중분류
# 살인기수           1      2      5      0       1      3     4    19
# ...

# %%
df[~filt]
# Out:
#           범죄대분류  서울  부산  대구  인천  광주  대전  울산  세종  경기 고양  ...  경남 밀양  경남 사천  \
# 범죄중분류                                                   ...
# 살인기수       강력범죄  35  29  16  14   1   6   8   2      6  ...      1      2
# 기타강간강제추행등  강력범죄  35  14   9  16   8   2  10   1      4  ...      1      1
# 유가증권인지     지능범죄  25   7   3   0   1   0   0   0      2  ...      0      0
#
#            경남 양산  경남 진주  경남 창원  경남 통영  제주 서귀포  제주 제주  기타도시  도시이외
# 범죄중분류
# 살인기수           1      2      5      0       1      3     4    19
# 기타강간강제추행등      0      1      5      2       0      3     1    23
# 유가증권인지         0      1      0      0       0      1     2     1
#
# [3 rows x 88 columns]

# %%
df.loc[filt, ['대구', '울산']]
# Out:
#            대구  울산
# 범죄중분류
# 살인기수       16   8
# 살인미수등      15   7
# 기타강간강제추행등   9  10
# 약취유인        7   5
# 증수뢰         7   7
# 유가증권인지      3   0
# 환경범죄       16  29
# 노동범죄       19   1
# 안보범죄        6   4

# %%
df[df['서울'] <= 100]
# Out:
#           범죄대분류  서울   부산  대구  인천  광주  대전  울산  세종  경기 고양  ...  경남 밀양  경남 사천  \
# 범죄중분류                                                    ...
# 살인기수       강력범죄  35   29  16  14   1   6   8   2      6  ...      1      2
# 살인미수등      강력범죄  68   24  15  38   2  11   7   3      8  ...      2      0
# 기타강간강제추행등  강력범죄  35   14   9  16   8   2  10   1      4  ...      1      1
# 약취유인       폭력범죄  72   17   7  18   8   2   5   2     10  ...      0      0
# 증수뢰        지능범죄  71   17   7  21  11  13   7   1      2  ...      0      0
# 유가증권인지     지능범죄  25    7   3   0   1   0   0   0      2  ...      0      0
# 환경범죄       환경범죄  50  243  16  87   7  23  29   7     46  ...     36     46
# 노동범죄       노동범죄  83   37  19  14   9  21   1   0     21  ...      1      1
# 안보범죄       안보범죄  61   13   6   7   4   4   4   2      0  ...      0      0
#
#            경남 양산  경남 진주  경남 창원  경남 통영  제주 서귀포  제주 제주  기타도시  도시이외
# 범죄중분류
# 살인기수           1      2      5      0       1      3     4    19
# ...

# %%
df.loc[df['서울'] <= 100, '경기 고양']
# Out:
# 범죄중분류
# 살인기수          6
# 살인미수등         8
# 기타강간강제추행등     4
# 약취유인         10
# 증수뢰           2
# 유가증권인지        2
# 환경범죄         46
# 노동범죄         21
# 안보범죄          0
# Name: 경기 고양, dtype: int64

# %%
df.loc[(df['서울'] <= 500) & (df['대구'] == 16)]
# Out:
#       범죄대분류  서울   부산  대구  인천  광주  대전  울산  세종  경기 고양  ...  경남 밀양  경남 사천  경남 양산  \
# 범죄중분류                                                ...
# 살인기수   강력범죄  35   29  16  14   1   6   8   2      6  ...      1      2      1
# 환경범죄   환경범죄  50  243  16  87   7  23  29   7     46  ...     36     46      7
#
#        경남 진주  경남 창원  경남 통영  제주 서귀포  제주 제주  기타도시  도시이외
# 범죄중분류
# 살인기수       2      5      0       1      3     4    19
# 환경범죄      31     71     33      11     21    49   574
#
# [2 rows x 88 columns]

# %%
df.loc[(df['서울'] <= 500) & (df['대구'] <= 10)]
# Out:
#           범죄대분류  서울  부산  대구  인천  광주  대전  울산  세종  경기 고양  ...  경남 밀양  경남 사천  \
# 범죄중분류                                                   ...
# 기타강간강제추행등  강력범죄  35  14   9  16   8   2  10   1      4  ...      1      1
# 약취유인       폭력범죄  72  17   7  18   8   2   5   2     10  ...      0      0
# 증수뢰        지능범죄  71  17   7  21  11  13   7   1      2  ...      0      0
# 유가증권인지     지능범죄  25   7   3   0   1   0   0   0      2  ...      0      0
# 안보범죄       안보범죄  61  13   6   7   4   4   4   2      0  ...      0      0
#
#            경남 양산  경남 진주  경남 창원  경남 통영  제주 서귀포  제주 제주  기타도시  도시이외
# 범죄중분류
# 기타강간강제추행등      0      1      5      2       0      3     1    23
# 약취유인           1      5      1      0       0      1     1    11
# 증수뢰            3      2      7      0       0      1    11    31
# 유가증권인지         0      1      0      0       0      1     2     1
# 안보범죄           0      1      1      0       2      1    12     9
#
# [5 rows x 88 columns]

# %%
filt = df['범죄대분류'].str.startswith('지능')
df[filt]
# Out:
#        범죄대분류     서울     부산     대구     인천    광주     대전    울산    세종  경기 고양  ...  \
# 범죄중분류                                                                     ...
# 직무유기    지능범죄    353    130     64     95    31     33    18    26      5  ...
# 직권남용    지능범죄    392    156     47     78    64     51    19    21     24  ...
# 증수뢰     지능범죄     71     17      7     21    11     13     7     1      2  ...
# 통화      지능범죄    172     20     27     29    10      7     1     3     11  ...
# 문서인장    지능범죄   2033    897    459    581   319    336   206    70    182  ...
# 유가증권인지  지능범죄     25      7      3      0     1      0     0     0      2  ...
# 사기      지능범죄  52034  26847  14836  16652  8249  11734  5615  1528   5201  ...
# 횡령      지능범죄  16368   4469   2643   4175  1666   1456   759   248   1737  ...
# 배임      지능범죄    791    273    106    184   112    105    72    13     63  ...
#
#         경남 밀양  경남 사천  경남 양산  경남 진주  경남 창원  경남 통영  제주 서귀포  제주 제주   기타도시   도시이외
# 범죄중분류
# ...

# %%
filt = df['범죄대분류'].str.contains('강')
df[filt]
# Out:
#           범죄대분류    서울    부산   대구    인천   광주   대전   울산  세종  경기 고양  ...  경남 밀양  \
# 범죄중분류                                                             ...
# 살인기수       강력범죄    35    29   16    14    1    6    8   2      6  ...      1
# 살인미수등      강력범죄    68    24   15    38    2   11    7   3      8  ...      2
# 강도         강력범죄   118    43   31    30   10   17   10   2      4  ...      1
# 강간         강력범죄  1200   347  215   340  152  200  112  26     63  ...      6
# 유사강간       강력범죄   219    83   43    61   32   34   14   6     13  ...      0
# 강제추행       강력범죄  4358  1064  648  1030  391  500  311  73    241  ...     23
# 기타강간강제추행등  강력범죄    35    14    9    16    8    2   10   1      4  ...      1
# 방화         강력범죄   217    89   50    70   35   40   28   8     19  ...      5
#
#            경남 사천  경남 양산  경남 진주  경남 창원  경남 통영  제주 서귀포  제주 제주  기타도시  도시이외
# 범죄중분류
# 살인기수           2      1      2      5      0       1      3     4    19
# ...

# %%
df[~filt]
# Out:
#          범죄대분류     서울     부산     대구     인천    광주     대전    울산    세종  경기 고양  \
# 범죄중분류
# 절도범죄      절도범죄  37594  13699   9792   8895  5204   6034  3283  1110   2484
# 상해        폭력범죄   3353   2478   1568   1545   641    831   683   119    267
# 폭행        폭력범죄  26509   8474   5629   8040  3430   4166  2574   400   2414
# 체포감금      폭력범죄    243     66     41    100    33     31    35     3     18
# 협박        폭력범죄   4162   1402    933   1411   424    595   397    86    450
# 약취유인      폭력범죄     72     17      7     18     8      2     5     2     10
# 폭력행위등     폭력범죄   1075    572    277    501   196    211   198    25    119
# 공갈        폭력범죄   1056    503    189    591   113    232    71    25     68
# 손괴        폭력범죄  10240   3730   2716   3089  1457   1696  1079   250    860
# 직무유기      지능범죄    353    130     64     95    31     33    18    26      5
# 직권남용      지능범죄    392    156     47     78    64     51    19    21     24
# ...

# %%
langs = [9792, 1568]
filt = df['대구'].isin(langs)
df[filt]
# Out:
#       범죄대분류     서울     부산    대구    인천    광주    대전    울산    세종  경기 고양  ...  \
# 범죄중분류                                                                 ...
# 절도범죄   절도범죄  37594  13699  9792  8895  5204  6034  3283  1110   2484  ...
# 상해     폭력범죄   3353   2478  1568  1545   641   831   683   119    267  ...
#
#        경남 밀양  경남 사천  경남 양산  경남 진주  경남 창원  경남 통영  제주 서귀포  제주 제주  기타도시  도시이외
# 범죄중분류
# 절도범죄     308    342   1158   2114   3426    387     886   2247    43  9454
# 상해       121    113    221    251    635    134     213    351    16  2612
#
# [2 rows x 88 columns]

# %%
df['범죄대분류'].str.contains('안')
# Out:
# 범죄중분류
# 살인기수         False
# 살인미수등        False
# 강도           False
# 강간           False
# 유사강간         False
# 강제추행         False
# 기타강간강제추행등    False
# 방화           False
# 절도범죄         False
# 상해           False
# 폭행           False
# 체포감금         False
# 협박           False
# 약취유인         False
# 폭력행위등        False
# 공갈           False
# 손괴           False
# 직무유기         False
# 직권남용         False
# 증수뢰          False
# 통화           False
# 문서인장         False
# 유가증권인지       False
# 사기           False
# 횡령           False
# 배임           False
# 성풍속범죄        False
# 도박범죄         False
# 특별경제범죄       False
# 마약범죄         False
# 보건범죄         False
# 환경범죄         False
# 교통범죄         False
# 노동범죄         False
# 안보범죄          True
# 선거범죄         False
# 병역범죄         False
# 기타범죄         False
# Name: 범죄대분류, dtype: bool
