# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('data/QuizData.csv')
dataset.head()
# Out:
#    total  reception
# 0    118         62
# 1    253        148
# 2    320        201
# 3     94         80
# 4    155         92

# %%
X = dataset.iloc[:,:-1].values
y= dataset.iloc[:,-1].values
X[:5], y[:5]
# Out:
# (array([[118],
#         [253],
#         [320],
#         [ 94],
#         [155]]),
#  array([ 62, 148, 201,  80,  92]))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
X_train, y_train
# Out:
# (array([[253],
#         [186],
#         [129],
#         [392],
#         [118],
#         [262],
#         [179],
#         [288],
#         [ 86],
#         [320],
#         [112],
#         [188],
#         [201],
#         [223],
#         [223],
#         [155]]),
#  array([148, 124,  76, 199,  62, 183, 101, 152,  58, 201,  68, 131, 147,
#         143, 149,  92]))

# %%
plt.scatter(X_train, y_train, color='blue')
plt.plot(X_train, reg.predict(X_train), color='green')
plt.title('Wedding reception(train)')
plt.xlabel('total')
plt.ylabel('reception')
plt.show()

# %%
plt.scatter(X_test, y_test, color='blue')
plt.plot(X_train, reg.predict(X_train), color='green')
plt.title('Wedding reception(test)')
plt.xlabel('total')
plt.ylabel('reception')
plt.show()

# %%
reg.score(X_train, y_train), reg.score(X_test, y_test)
# Out:
# (0.889237764872611, 0.7787957349123683)

# %%
total = 300
y_pred = reg.predict([[total]])
print(f'결혼식 인원 {total}명에 대한 예상 식수 인원은 {np.round(y_pred[0]).astype(int)}입니다.')
# Out:
# 결혼식 인원 300명에 대한 예상 식수 인원은 177입니다.
