# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
font_path = "C:\\Users\\KOSMO\\AppData\\Local\\Microsoft\\Windows\\Fonts\\강원교육모두 Bold.ttf"
font_name = fm.FontProperties(fname=font_path).get_name()
plt.rc('font', family=font_name)

# %%
df=pd.read_excel('data/2022~2011 출생아수와 출산율.xlsx', skiprows=2, nrows=2, index_col=0)
df
# Out:
# c:\Users\KOSMO\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#            2012     2013     2014     2015     2016     2017     2018  \
# 출생아 수   484.600  436.500  435.400  438.400  406.200  357.800  326.800
# 합계 출산율    1.297    1.187    1.205    1.239    1.172    1.052    0.977
#
#            2019     2020     2021
# 출생아 수   302.700  272.300  260.600
# 합계 출산율    0.918    0.837    0.808

# %%
df.index
# Out:
# Index(['출생아 수', '합계 출산율'], dtype='object')

# %%
df.index.values
# Out:
# array(['출생아\xa0수', '합계\xa0출산율'], dtype=object)

# %%
df.rename(index={'출생아\xa0수':'출생아 수', '합계\xa0출산율':'합계 출산율'}, inplace=True)
df
# Out:
#            2012     2013     2014     2015     2016     2017     2018  \
# 출생아 수   484.600  436.500  435.400  438.400  406.200  357.800  326.800
# 합계 출산율    1.297    1.187    1.205    1.239    1.172    1.052    0.977
#
#            2019     2020     2021
# 출생아 수   302.700  272.300  260.600
# 합계 출산율    0.918    0.837    0.808

# %%
df.index.values
# Out:
# array(['출생아 수', '합계 출산율'], dtype=object)

# %%
df.loc[['출생아 수']]
# Out:
#         2012   2013   2014   2015   2016   2017   2018   2019   2020   2021
# 출생아 수  484.6  436.5  435.4  438.4  406.2  357.8  326.8  302.7  272.3  260.6

# %%
df.iloc[[0]]
# Out:
#         2012   2013   2014   2015   2016   2017   2018   2019   2020   2021
# 출생아 수  484.6  436.5  435.4  438.4  406.2  357.8  326.8  302.7  272.3  260.6

# %%
df = df.T
df
# Out:
#       출생아 수  합계 출산율
# 2012  484.6   1.297
# 2013  436.5   1.187
# 2014  435.4   1.205
# 2015  438.4   1.239
# 2016  406.2   1.172
# 2017  357.8   1.052
# 2018  326.8   0.977
# 2019  302.7   0.918
# 2020  272.3   0.837
# 2021  260.6   0.808

# %%
plt.plot(df.index, df['출생아 수'])
plt.plot(df.index, df['합계 출산율'])

# %%
fig, ax1 = plt.subplots(figsize=(10, 5))
ax1.plot(df.index, df['출생아 수'], color='#111')
ax2 = ax1.twinx() #x축을 공유하는 쌍둥이 axis
ax2.plot(df.index, df['합계 출산율'], color='#f1a1b1')

# %%
fig, ax1 = plt.subplots(figsize=(10, 5))
ax1.bar(df.index, df['출생아 수'], color='#a1b1c1')
ax1.set_ylabel('출생아 수 (천 명)')
ax2 = ax1.twinx()
ax2.plot(df.index, df['합계 출산율'], color='#f1a1b1')
ax2.set_ylabel('합계 출산율 (가임여성 1명당 명)')
# Out:
# Text(0, 0.5, '합계 출산율 (가임여성 1명당 명)')

# %%
fig, ax1 = plt.subplots(figsize=(13, 5))
ax1.bar(df.index, df['출생아 수'], color='#a1b1c1')
ax1.set_ylabel('출생아 수 (천 명)')
ax1.set_ylim(250, 550)
ax1.set_yticks([300, 400, 500, 600])
ax2 = ax1.twinx()
ax2.plot(df.index, df['합계 출산율'], color='#f1a1b1')
ax2.set_ylabel('합계 출산율 (가임여성 1명당 명)')
ax2.set_ylim(0, 1.5)
ax2.set_yticks([0, 1, 1.5])
# Out:
# [<matplotlib.axis.YTick at 0x1669e725ca0>,
#  <matplotlib.axis.YTick at 0x1669f0995b0>,
#  <matplotlib.axis.YTick at 0x1669f0672c0>]

# %%
fig, ax1 = plt.subplots(figsize=(13, 5))
fig.suptitle('출생아 수 및 합계출산율')
ax1.bar(df.index, df['출생아 수'], color='#a1b1c1')
ax1.set_ylabel('출생아 수 (천 명)')
ax1.set_ylim(250, 550)
ax1.set_yticks([300, 400, 500])
for idx, val in enumerate(df['출생아 수']): ax1.text(idx, val+5, val, ha='center')
ax2 = ax1.twinx()
ax2.plot(df.index, df['합계 출산율'], color='#f1a1b1', marker='o', ms=15, lw=2, mec='w', mew=1)
ax2.set_ylabel('합계 출산율 (가임여성 1명당 명)')
ax2.set_ylim(0, 1.5)
ax2.set_yticks([0, 1])
for idx, val in enumerate(df['합계 출산율']): ax2.text(idx, val+0.05, val, ha='center')
