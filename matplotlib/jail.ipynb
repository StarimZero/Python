# %%
import pandas as pd
df = pd.read_csv('data/경찰청_범죄 발생 지역별 통계_20221231.csv', encoding='euc-kr', index_col='범죄중분류')
df
# Out:
#             범죄대분류     서울     부산     대구     인천    광주     대전    울산    세종  경기 고양  \
# 범죄중분류
# 살인기수         강력범죄     35     29     16     14     1      6     8     2      6
# 살인미수등        강력범죄     68     24     15     38     2     11     7     3      8
# 강도           강력범죄    118     43     31     30    10     17    10     2      4
# 강간           강력범죄   1200    347    215    340   152    200   112    26     63
# 유사강간         강력범죄    219     83     43     61    32     34    14     6     13
# 강제추행         강력범죄   4358   1064    648   1030   391    500   311    73    241
# 기타강간강제추행등    강력범죄     35     14      9     16     8      2    10     1      4
# 방화           강력범죄    217     89     50     70    35     40    28     8     19
# 절도범죄         절도범죄  37594  13699   9792   8895  5204   6034  3283  1110   2484
# 상해           폭력범죄   3353   2478   1568   1545   641    831   683   119    267
# 폭행           폭력범죄  26509   8474   5629   8040  3430   4166  2574   400   2414
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
font_path = "C:\\Users\\KOSMO\\AppData\\Local\\Microsoft\\Windows\\Fonts\\강원교육모두 Bold.ttf"
font_name = fm.FontProperties(fname=font_path).get_name()
plt.rc('font', family=font_name)

# %%
df
# Out:
#             범죄대분류     서울     부산     대구     인천    광주     대전    울산    세종  경기 고양  \
# 범죄중분류
# 살인기수         강력범죄     35     29     16     14     1      6     8     2      6
# 살인미수등        강력범죄     68     24     15     38     2     11     7     3      8
# 강도           강력범죄    118     43     31     30    10     17    10     2      4
# 강간           강력범죄   1200    347    215    340   152    200   112    26     63
# 유사강간         강력범죄    219     83     43     61    32     34    14     6     13
# 강제추행         강력범죄   4358   1064    648   1030   391    500   311    73    241
# 기타강간강제추행등    강력범죄     35     14      9     16     8      2    10     1      4
# 방화           강력범죄    217     89     50     70    35     40    28     8     19
# 절도범죄         절도범죄  37594  13699   9792   8895  5204   6034  3283  1110   2484
# 상해           폭력범죄   3353   2478   1568   1545   641    831   683   119    267
# 폭행           폭력범죄  26509   8474   5629   8040  3430   4166  2574   400   2414
# ...

# %%
values = list(df.iloc[1])
labels = list(df.index)

# %%
explode = [.1] * len(values)
colors=['r', 'g', 'b', 'c', 'm', 'y', 'orange', '#FFADAD','#FFD6A5','#FDFFB6','#CAFFBF','#9BF6FF','#A0C4FF']
plt.pie(values, labels = labels, autopct='%.1f%%', startangle=90, counterclock=False, explode=explode, colors=colors)
plt.legend(loc=(1.2, 0.3))
plt.show() #'%.1f%%' 소수점 첫째 자리 % 포함 출력
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 3
#       1 explode = [.1] * len(values)
#       2 colors=['r', 'g', 'b', 'c', 'm', 'y', 'orange', '#FFADAD','#FFD6A5','#FDFFB6','#CAFFBF','#9BF6FF','#A0C4FF']
# ----> 3 plt.pie(values, labels = labels, autopct='%.1f%%', startangle=90, counterclock=False, explode=explode, colors=colors)
#       4 plt.legend(loc=(1.2, 0.3))
#       5 plt.show() #'%.1f%%' 소수점 첫째 자리 % 포함 출력
#
# File c:\Users\KOSMO\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:3762, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    3739 @_copy_docstring_and_deprecators(Axes.pie)
#    3740 def pie(
#    3741     x: ArrayLike,
#    (...)
#    3760     data=None,
# ...
